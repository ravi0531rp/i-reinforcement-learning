# %%
# !pip install 'stable-baselines3[extra]'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 1.4 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.8/133.8 MB 9.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 20.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 23.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached numpy-1.23.2-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.9 MB/s eta 0:00:00m eta 0:00:010:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.7/961.7 kB 19.9 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 15.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached Pillow-9.2.0-cp39-cp39-macosx_10_10_x86_64.whl (3.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 24.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
# !pip install 'gym[all]'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 14.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.8 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.3/986.3 kB 24.3 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 31.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import os
import gym
from stable_baselines3 import PPO # the algorithm itself
from stable_baselines3.common.vec_env import DummyVecEnv # to vectorize environments (parallel training)
from stable_baselines3.common.evaluation import evaluate_policy # to evaluate the scores
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a9b15ec38b96> in <module>
#       1 import os
# ----> 2 from stable_baselines3 import PPO # the algorithm itself
#       3 from stable_baselines3.common.vec_env import DummyVecEnv # to vectorize environments (parallel training)
#       4 from stable_baselines3.common.evaluation import evaluate_policy # to evaluate the scores
#
# ModuleNotFoundError: No module named 'stable_baselines3'

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

# %%
print(env.action_space)
print(env.action_space.sample())
print(env.action_space.sample())
# Out:
# Discrete(2)
# 0
# 1

# %%
print(env.observation_space)
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.reset()
env.step(env.action_space.sample())
# Out:
# (array([ 0.02276622,  0.2214848 ,  0.01126718, -0.24545412], dtype=float32),
#  1.0,
#  False,
#  {})

# %% [markdown]
# ### Understanding the ENVIRONMENT

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print(f"Episode {episode} ended with score {score}")

env.close()
# Out:
# 2022-09-09 22:57:19.955 python[73694:1848722] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fa69bad6c90>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-09 22:57:19.956 python[73694:1848722] Warning: Expected min height of view: (<NSButton: 0x7fa69bac19a0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-09 22:57:19.959 python[73694:1848722] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fa69bac4ea0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-09 22:57:19.962 python[73694:1848722] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fa69baca910>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# ...

# %%
log_path = os.path.join('Training' , 'logs')

# %%
log_path
# Out:
# 'Training/logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda : env])
model = PPO('MlpPolicy', env , verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
PPO_path = os.path.join('Training','saved_models','PPO_Cartpole')
# Out:
# Logging to Training/logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1823 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1283         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0089352075 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.0149      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.21         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0183      |
# ...

# %%
model??
# Out:
# Type:        PPO
# String form: <stable_baselines3.ppo.ppo.PPO object at 0x7f90b781ba00>
# File:        ~/opt/anaconda3/envs/RL/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py
# Source:
# class PPO(OnPolicyAlgorithm):
#     """
#     Proximal Policy Optimization algorithm (PPO) (clip version)
#
#     Paper: https://arxiv.org/abs/1707.06347
#     Code: This implementation borrows code from OpenAI Spinning Up (https://github.com/openai/spinningup/)
#     https://github.com/ikostrikov/pytorch-a2c-ppo-acktr-gail and
#     Stable Baselines (PPO2 from https://github.com/hill-a/stable-baselines)
#
#     Introduction to PPO: https://spinningup.openai.com/en/latest/algorithms/ppo.html
#
#     :param policy: The policy model to use (MlpPolicy, CnnPolicy, ...)
#     :param env: The environment to learn from (if registered in Gym, can be str)
#     :param learning_rate: The learning rate, it can be a function
#         of the current progress remaining (from 1 to 0)
# ...

# %% [markdown]
# ### Save and Reload the model

# %%
PPO_path = os.path.join('Training','saved_models','PPO_Cartpole')

# %%
model.save(PPO_path)
# Out:
# /Users/raprak-blrm20/opt/anaconda3/envs/RL/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'Training/saved_models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
model = PPO.load(PPO_path)

# %% [markdown]
# ### Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False) # 200 avg is perfect for this game
# Out:
# /Users/raprak-blrm20/opt/anaconda3/envs/RL/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
model.predict(env.reset())  # gives action and next_state (here None as the algo doesn't support)
# Out:
# (array([1]), None)

# %%
model.predict??
# Out:
# Signature:
# model.predict(
#     observation: numpy.ndarray,
#     state: Optional[Tuple[numpy.ndarray, ...]] = None,
#     episode_start: Optional[numpy.ndarray] = None,
#     deterministic: bool = False,
# ) -> Tuple[numpy.ndarray, Optional[Tuple[numpy.ndarray, ...]]]
# Source:
#     def predict(
#         self,
#         observation: np.ndarray,
#         state: Optional[Tuple[np.ndarray, ...]] = None,
#         episode_start: Optional[np.ndarray] = None,
#         deterministic: bool = False,
#     ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#         """
#         Get the policy action from an observation (and optional hidden state).
#         Includes sugar-coating to handle different observations (e.g. normalizing images).
#
#         :param observation: the input observation
#         :param state: The last hidden states (can be None, used in recurrent policies)
#         :param episode_start: The last masks (can be None, used in recurrent policies)
# ...

# %%
# tensorboard --logdir=/Users/raprak-blrm20/Desktop/personal/codes/G-CORE-RL/a-reinf-yt/Training/logs/PPO_1
